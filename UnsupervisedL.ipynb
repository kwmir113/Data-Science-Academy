# %% [markdown]
# <a href="https://colab.research.google.com/github/kwmir113/Data-Science-Academy/blob/main/UnsupervisedL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Code snippet 1
# Importing the dataset
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/nvamsimohan/DallasDSA/refs/heads/main/Zillow%20Tarrant%20County%20Raw%20Data.csv')
data
# Out:
#       beds  baths  sqft  Age  lot_size                  property_type  \
# 0        1      1   584    9         0  Apartment / Condo / Townhouse
# 1        1      1   612   57         0  Apartment / Condo / Townhouse
# 2        1      1   615   59         0  Apartment / Condo / Townhouse
# 3        1      1   618   22     33541  Apartment / Condo / Townhouse
# 4        1      1   634   30         0  Apartment / Condo / Townhouse
# ...    ...    ...   ...  ...       ...                            ...
# 1878     5      6  6381   18    224334                  Single-Family
# 1879     5      6  6501   66     23086                  Single-Family
# 1880     5      6  7064   27    217800                  Single-Family
# 1881     5      6  7500   16      8886                  Single-Family
# 1882     5      6  7515   64     10497                  Single-Family
#
#            exterior_walls                 roof  basement  restaurants  ...  \
# ...

# %%
# Code snippet 2
# Displaying dataset columns
data.columns
# Out:
# Index(['beds', 'baths', 'sqft', 'Age', 'lot_size', 'property_type',
#        'exterior_walls', 'roof', 'basement', 'restaurants', 'groceries',
#        'nightlife', 'cafes', 'shopping', 'arts_entertainment', 'beauty_spas',
#        'active_life', 'median_age', 'married', 'college_grad', 'property_tax',
#        'insurance', 'median_school', 'num_schools', 'Sales_price'],
#       dtype='object')

# %%
# Code snippet 2
# Checking the missing data %
import missingno as msno
msno.bar(data)
# Out:
# <Axes: >
